# %% [markdown]
# ## Lost a notebook on CSV file. Get it from someone later on

# %%
import pandas as pd

filePath = '/Users/yogeshchandrasekharuni/Downloads/seasonsamplefile.csv'

def readCsvFile(filepath):
    return pd.read_csv(filepath)

df = readCsvFile(filePath)

# %% [markdown]
# # Groupby

# %%
df.columns.tolist()
# Out:
# ['Season', 'Daynum', 'Wteam', 'Wscore', 'Lteam', 'Lscore', 'Wloc', 'Numot']

# %%
df.groupby('Wteam')['Wscore'].mean().head()
# Out:
# Wteam
# 1101    78.111111
# 1102    69.893204
# 1103    75.839768
# 1104    75.825944
# 1105    74.960894
# Name: Wscore, dtype: float64

# %%
df.groupby("Season")["Wteam"].mean().head()
# Out:
# Season
# 1985    1287.701097
# 1986    1285.545863
# 1987    1284.852107
# 1988    1284.863970
# 1989    1283.772851
# Name: Wteam, dtype: float64

# %% [markdown]
# ## Data-Cleaning

# %%
# Entire data set

df.isnull().sum()
# Out:
# Season    0
# Daynum    0
# Wteam     0
# Wscore    0
# Lteam     0
# Lscore    0
# Wloc      0
# Numot     0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Season    0
# Daynum    0
# Wteam     0
# Wscore    0
# Lteam     0
# Lscore    0
# Wloc      0
# Numot     0
# dtype: int64

# %%
df.shape
# Out:
# (145289, 8)

# %%
new_df = df.dropna(axis = 0, how = 'any')

len(new_df)
# Out:
# 145289

# %%
df.shape
# Out:
# (145289, 8)

# %%
df['Season'].fillna('Testing', inplace=True)
df
# Out:
#          Season  Daynum  Wteam  Wscore  Lteam  Lscore Wloc  Numot
# 0          1985      20   1228      81   1328      64    N      0
# 1          1985      25   1106      77   1354      70    H      0
# 2          1985      25   1112      63   1223      56    H      0
# 3          1985      25   1165      70   1432      54    H      0
# 4          1985      25   1192      86   1447      74    H      0
# 5          1985      25   1218      79   1337      78    H      0
# 6          1985      25   1228      64   1226      44    N      0
# 7          1985      25   1242      58   1268      56    N      0
# 8          1985      25   1260      98   1133      80    H      0
# 9          1985      25   1305      97   1424      89    H      0
# 10         1985      25   1307     103   1288      71    H      0
# 11         1985      25      0      75   1438      71    N      0
# 12         1985      25   1374      91   1411      72    H      0
# ...
